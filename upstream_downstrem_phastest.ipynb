# %% [markdown]
# I wanted to check what the upstream and downstream regions of the phastest predicted sites are to answer if:
# - phages that are similar have specific region they like to integarate
# - are there any common features or genes that are present in this regions
#
# I will be doing this using the fasta files present in `/Users/pjoglekar/work/pseudomonas/Pseudomonas_data_from_selected_genomes/pacbio_genomes/fasta_files`. I extracted the regions.txt from each Phastest predicted region and created a merged summary for these files in the tsv format available here `/Users/pjoglekar/work/pseudomonas/Pseudomonas_data_from_selected_genomes/pacbio_genomes/statistical_analysis/phastest_merge_summaries.tsv`

# %%
#Step 1: import required packages

import pandas as pd
from Bio import SeqIO
import os

# Create output directories if they don't exist
os.makedirs("upstream_seq_1500", exist_ok=True)
os.makedirs("downstream_seq_1500", exist_ok=True)

# %%
#Step 2: set input files and process the file names

#paths for files
# Paths
tsv_file = '/Users/pjoglekar/work/pseudomonas/Pseudomonas_data_from_selected_genomes/pacbio_genomes/statistical_analysis/phastest_merge_summaries.tsv'
fasta_dir = '/Users/pjoglekar/work/pseudomonas/Pseudomonas_data_from_selected_genomes/pacbio_genomes/fasta_files'

# %%
# Read TSV
df = pd.read_csv(tsv_file, sep='\t')

#Step 3:  Prepare output table
output_rows = []

for idx, row in df.iterrows():
    organism = row['ORGANISM']
    region = row['REGION']
    region_length = row['REGION_LENGTH']
    completeness = row['COMPLETENESS(score)']
    region_position = row['REGION_POSITION']

    fasta_base = organism.split('_contig')[0]
    contig_name = organism
    fasta_file = f"{fasta_dir}/{fasta_base}.fasta"

    for record in SeqIO.parse(fasta_file, "fasta"):
        if record.id == contig_name:
            seq = record.seq
            if '-' in region_position:
                start, end = map(int, region_position.split('-'))
            else:
                start = end = int(region_position)

            up_start = max(0, start-1500)
            up_end = start
            down_start = end
            down_end = min(len(seq), end+1500)

            # Track which extractions are valid
            valid_upstream = up_end > up_start and up_end <= len(seq)
            valid_downstream = down_end > down_start and down_end <= len(seq)

            # Extract and write only valid sequences
            if valid_upstream:
                upstream_seq = seq[up_start:up_end]
                up_fasta = f"upstream_seq_1500/{fasta_base}_{region}_upstream.fasta"
                SeqIO.write([record[up_start:up_end]], up_fasta, "fasta")
            else:
                print(f"Skipping upstream for region {region} in {organism}: invalid coordinates ({up_start}-{up_end})")

            if valid_downstream:
                downstream_seq = seq[down_start:down_end]
                down_fasta = f"downstream_seq_1500/{fasta_base}_{region}_downstream.fasta"
                SeqIO.write([record[down_start:down_end]], down_fasta, "fasta")
            else:
                print(f"Skipping downstream for region {region} in {organism}: invalid coordinates ({down_start}-{down_end})")

            # Record output, showing which coordinates were valid
            output_rows.append({
                'ORGANISM': organism,
                'REGION': region,
                'REGION_POSITION': region_position,
                'UPSTREAM_COORDS': f"{up_start}-{up_end}" if valid_upstream else "invalid",
                'DOWNSTREAM_COORDS': f"{down_start}-{down_end}" if valid_downstream else "invalid"
            })
            break
# Out:
# Skipping upstream for region 1 in Ps_papulans_renamed_contig_1: invalid coordinates (234205-235705)
# Skipping downstream for region 1 in Ps_papulans_renamed_contig_1: invalid coordinates (275183-103811)
# Skipping upstream for region 2 in Ps_papulans_renamed_contig_1: invalid coordinates (354679-356179)
# Skipping downstream for region 2 in Ps_papulans_renamed_contig_1: invalid coordinates (375607-103811)
# Skipping upstream for region 3 in Ps_papulans_renamed_contig_1: invalid coordinates (432686-434186)
# Skipping downstream for region 3 in Ps_papulans_renamed_contig_1: invalid coordinates (458413-103811)
# Skipping upstream for region 4 in Ps_papulans_renamed_contig_1: invalid coordinates (2678618-2680118)
# Skipping downstream for region 4 in Ps_papulans_renamed_contig_1: invalid coordinates (2692497-103811)
# Skipping upstream for region 5 in Ps_papulans_renamed_contig_1: invalid coordinates (2812569-2814069)
# Skipping downstream for region 5 in Ps_papulans_renamed_contig_1: invalid coordinates (2825503-103811)
# Skipping upstream for region 6 in Ps_papulans_renamed_contig_1: invalid coordinates (2955820-2957320)
# Skipping downstream for region 6 in Ps_papulans_renamed_contig_1: invalid coordinates (2975384-103811)
# Skipping upstream for region 7 in Ps_papulans_renamed_contig_1: invalid coordinates (4457005-4458505)
# Skipping downstream for region 7 in Ps_papulans_renamed_contig_1: invalid coordinates (4508810-103811)
# Skipping upstream for region 8 in Ps_papulans_renamed_contig_1: invalid coordinates (4546018-4547518)
# Skipping downstream for region 8 in Ps_papulans_renamed_contig_1: invalid coordinates (4608169-103811)
# Skipping upstream for region 9 in Ps_papulans_renamed_contig_1: invalid coordinates (5800241-5801741)
# Skipping downstream for region 9 in Ps_papulans_renamed_contig_1: invalid coordinates (5846930-103811)
# Skipping upstream for region 1 in NCSU_AHP167_contig_1: invalid coordinates (5287284-5288784)
# Skipping downstream for region 1 in NCSU_AHP167_contig_1: invalid coordinates (5309249-900859)
# Skipping upstream for region 1 in P_caricapapayae_renamed_contig_1: invalid coordinates (1094892-1096392)
# Skipping downstream for region 1 in P_caricapapayae_renamed_contig_1: invalid coordinates (1135870-117531)
# Skipping upstream for region 2 in P_caricapapayae_renamed_contig_1: invalid coordinates (1214898-1216398)
# Skipping downstream for region 2 in P_caricapapayae_renamed_contig_1: invalid coordinates (1246153-117531)
# Skipping upstream for region 3 in P_caricapapayae_renamed_contig_1: invalid coordinates (3334555-3336055)
# Skipping downstream for region 3 in P_caricapapayae_renamed_contig_1: invalid coordinates (3350559-117531)
# Skipping upstream for region 4 in P_caricapapayae_renamed_contig_1: invalid coordinates (3466034-3467534)
# Skipping downstream for region 4 in P_caricapapayae_renamed_contig_1: invalid coordinates (3501707-117531)
# Skipping upstream for region 5 in P_caricapapayae_renamed_contig_1: invalid coordinates (4040431-4041931)
# Skipping downstream for region 5 in P_caricapapayae_renamed_contig_1: invalid coordinates (4081334-117531)
# Skipping upstream for region 6 in P_caricapapayae_renamed_contig_1: invalid coordinates (4178991-4180491)
# Skipping downstream for region 6 in P_caricapapayae_renamed_contig_1: invalid coordinates (4223881-117531)
# Skipping upstream for region 7 in P_caricapapayae_renamed_contig_1: invalid coordinates (4913865-4915365)
# Skipping downstream for region 7 in P_caricapapayae_renamed_contig_1: invalid coordinates (4960924-117531)
# Skipping downstream for region 4 in NCSU_AHP169_contig_1: invalid coordinates (6193520-6172518)
# Skipping downstream for region 4 in P_amygdali_contig_1: invalid coordinates (6246866-6241607)
# Skipping upstream for region 2 in NCSU_AHP195_contig_1: invalid coordinates (4606663-4608163)
# Skipping downstream for region 2 in NCSU_AHP195_contig_1: invalid coordinates (4647864-1235168)
# Skipping upstream for region 3 in NCSU_AHP195_contig_1: invalid coordinates (4643949-4645449)
# Skipping downstream for region 3 in NCSU_AHP195_contig_1: invalid coordinates (4669378-1235168)
# Skipping downstream for region 6 in NCSU_AHP192_contig_1: invalid coordinates (5190704-5168853)
# Skipping upstream for region 7 in NCSU_AHP192_contig_1: invalid coordinates (5997899-5999399)
# Skipping downstream for region 7 in NCSU_AHP192_contig_1: invalid coordinates (6040020-5168853)
# Skipping upstream for region 2 in Ps_dysoxyli_renamed_contig_1: invalid coordinates (3166543-3168043)
# Skipping downstream for region 2 in Ps_dysoxyli_renamed_contig_1: invalid coordinates (3202646-1414184)
# Skipping upstream for region 3 in Ps_dysoxyli_renamed_contig_1: invalid coordinates (5616322-5617822)
# Skipping downstream for region 3 in Ps_dysoxyli_renamed_contig_1: invalid coordinates (5638494-1414184)
# Skipping upstream for region 1 in Ps_aptata_renamed_contig_1: invalid coordinates (753097-754597)
# Skipping downstream for region 1 in Ps_aptata_renamed_contig_1: invalid coordinates (772001-79970)
# Skipping upstream for region 1 in P_cannabina_renamed_contig_1: invalid coordinates (594817-596317)
# Skipping downstream for region 1 in P_cannabina_renamed_contig_1: invalid coordinates (633582-40434)
# Skipping upstream for region 2 in P_cannabina_renamed_contig_1: invalid coordinates (2557414-2558914)
# Skipping downstream for region 2 in P_cannabina_renamed_contig_1: invalid coordinates (2573998-40434)
# Skipping upstream for region 1 in Ps_lapsa_renamed_contig_1: invalid coordinates (3764258-3765758)
# Skipping downstream for region 1 in Ps_lapsa_renamed_contig_1: invalid coordinates (3792144-150990)
# Skipping upstream for region 2 in Ps_lapsa_renamed_contig_1: invalid coordinates (4371065-4372565)
# Skipping downstream for region 2 in Ps_lapsa_renamed_contig_1: invalid coordinates (4391038-150990)
# Skipping upstream for region 3 in Ps_lapsa_renamed_contig_1: invalid coordinates (4789475-4790975)
# Skipping downstream for region 3 in Ps_lapsa_renamed_contig_1: invalid coordinates (4821077-150990)
# Skipping upstream for region 4 in Ps_lapsa_renamed_contig_1: invalid coordinates (5772132-5773632)
# Skipping downstream for region 4 in Ps_lapsa_renamed_contig_1: invalid coordinates (5819738-150990)
# Skipping upstream for region 1 in Ps_coryli_renamed_contig_1: invalid coordinates (517255-518755)
# Skipping downstream for region 1 in Ps_coryli_renamed_contig_1: invalid coordinates (541684-15573)
# Skipping upstream for region 2 in Ps_coryli_renamed_contig_1: invalid coordinates (2148706-2150206)
# Skipping downstream for region 2 in Ps_coryli_renamed_contig_1: invalid coordinates (2170723-15573)
# Skipping upstream for region 3 in Ps_coryli_renamed_contig_1: invalid coordinates (2215850-2217350)
# Skipping downstream for region 3 in Ps_coryli_renamed_contig_1: invalid coordinates (2235623-15573)
# Skipping upstream for region 4 in Ps_coryli_renamed_contig_1: invalid coordinates (3350385-3351885)
# Skipping downstream for region 4 in Ps_coryli_renamed_contig_1: invalid coordinates (3357768-15573)
# Skipping upstream for region 5 in Ps_coryli_renamed_contig_1: invalid coordinates (3389966-3391466)
# Skipping downstream for region 5 in Ps_coryli_renamed_contig_1: invalid coordinates (3414476-15573)
# Skipping upstream for region 6 in Ps_coryli_renamed_contig_1: invalid coordinates (4193283-4194783)
# Skipping downstream for region 6 in Ps_coryli_renamed_contig_1: invalid coordinates (4215194-15573)
# Skipping upstream for region 7 in Ps_coryli_renamed_contig_1: invalid coordinates (4746476-4747976)
# Skipping downstream for region 7 in Ps_coryli_renamed_contig_1: invalid coordinates (4757894-15573)
# Skipping upstream for region 1 in Ps_aceris_renamed_contig_1: invalid coordinates (1918471-1919971)
# Skipping downstream for region 1 in Ps_aceris_renamed_contig_1: invalid coordinates (1929913-5317)
# Skipping upstream for region 2 in Ps_aceris_renamed_contig_1: invalid coordinates (3205473-3206973)
# Skipping downstream for region 2 in Ps_aceris_renamed_contig_1: invalid coordinates (3258250-5317)
# Skipping upstream for region 3 in Ps_aceris_renamed_contig_1: invalid coordinates (3973965-3975465)
# Skipping downstream for region 3 in Ps_aceris_renamed_contig_1: invalid coordinates (3985294-5317)
# Skipping upstream for region 4 in Ps_aceris_renamed_contig_1: invalid coordinates (4113657-4115157)
# Skipping downstream for region 4 in Ps_aceris_renamed_contig_1: invalid coordinates (4129739-5317)
# Skipping upstream for region 5 in Ps_aceris_renamed_contig_1: invalid coordinates (4426436-4427936)
# Skipping downstream for region 5 in Ps_aceris_renamed_contig_1: invalid coordinates (4464613-5317)
# Skipping upstream for region 6 in Ps_aceris_renamed_contig_1: invalid coordinates (5209227-5210727)
# Skipping downstream for region 6 in Ps_aceris_renamed_contig_1: invalid coordinates (5227270-5317)
# Skipping upstream for region 1 in NCSU_AHP180_contig_1: invalid coordinates (900518-902018)
# Skipping downstream for region 1 in NCSU_AHP180_contig_1: invalid coordinates (959218-74414)
# Skipping upstream for region 2 in NCSU_AHP180_contig_1: invalid coordinates (1268755-1270255)
# Skipping downstream for region 2 in NCSU_AHP180_contig_1: invalid coordinates (1335444-74414)
# Skipping upstream for region 3 in NCSU_AHP180_contig_1: invalid coordinates (1887533-1889033)
# Skipping downstream for region 3 in NCSU_AHP180_contig_1: invalid coordinates (1939921-74414)
# Skipping upstream for region 4 in NCSU_AHP180_contig_1: invalid coordinates (4715020-4716520)
# Skipping downstream for region 4 in NCSU_AHP180_contig_1: invalid coordinates (4734252-74414)
# Skipping upstream for region 5 in NCSU_AHP180_contig_1: invalid coordinates (6374136-6375636)
# Skipping downstream for region 5 in NCSU_AHP180_contig_1: invalid coordinates (6418201-74414)
# Skipping upstream for region 6 in NCSU_AHP180_contig_1: invalid coordinates (6508697-6510197)
# Skipping downstream for region 6 in NCSU_AHP180_contig_1: invalid coordinates (6518112-74414)
# Skipping upstream for region 1 in P_amygdali_renamed_contig_1: invalid coordinates (571831-573331)
# Skipping downstream for region 1 in P_amygdali_renamed_contig_1: invalid coordinates (582427-67156)
# Skipping upstream for region 2 in P_amygdali_renamed_contig_1: invalid coordinates (3709886-3711386)
# Skipping downstream for region 2 in P_amygdali_renamed_contig_1: invalid coordinates (3721694-67156)
# Skipping upstream for region 3 in NCSU_AHP191_contig_1: invalid coordinates (5340490-5341990)
# Skipping downstream for region 3 in NCSU_AHP191_contig_1: invalid coordinates (5400000-4484935)
# Skipping upstream for region 1 in P_viridiflava_renamed_contig_1: invalid coordinates (279574-281074)
# Skipping downstream for region 1 in P_viridiflava_renamed_contig_1: invalid coordinates (323620-143466)
# Skipping upstream for region 2 in P_viridiflava_renamed_contig_1: invalid coordinates (550572-552072)
# Skipping downstream for region 2 in P_viridiflava_renamed_contig_1: invalid coordinates (570703-143466)
# Skipping upstream for region 1 in Ps_tomato_renamed_contig_1: invalid coordinates (655748-657248)
# Skipping downstream for region 1 in Ps_tomato_renamed_contig_1: invalid coordinates (687152-83848)
# Skipping upstream for region 2 in Ps_tomato_renamed_contig_1: invalid coordinates (3706327-3707827)
# Skipping downstream for region 2 in Ps_tomato_renamed_contig_1: invalid coordinates (3748497-83848)
# Skipping upstream for region 3 in Ps_tomato_renamed_contig_1: invalid coordinates (4805796-4807296)
# Skipping downstream for region 3 in Ps_tomato_renamed_contig_1: invalid coordinates (4840175-83848)
# Skipping upstream for region 1 in Pa_loropetalii_contig_1: invalid coordinates (1363835-1365335)
# Skipping downstream for region 1 in Pa_loropetalii_contig_1: invalid coordinates (1408533-149315)
# Skipping upstream for region 2 in Pa_loropetalii_contig_1: invalid coordinates (4134359-4135859)
# Skipping downstream for region 2 in Pa_loropetalii_contig_1: invalid coordinates (4155269-149315)
# Skipping upstream for region 3 in Pa_loropetalii_contig_1: invalid coordinates (4293186-4294686)
# Skipping downstream for region 3 in Pa_loropetalii_contig_1: invalid coordinates (4313586-149315)
# Skipping upstream for region 4 in Pa_loropetalii_contig_1: invalid coordinates (6156507-6158007)
# Skipping downstream for region 4 in Pa_loropetalii_contig_1: invalid coordinates (6198446-149315)
# Skipping upstream for region 5 in Pa_loropetalii_contig_1: invalid coordinates (6492567-6494067)
# Skipping downstream for region 5 in Pa_loropetalii_contig_1: invalid coordinates (6526518-149315)
# Skipping upstream for region 1 in Ps_atrofaciens_renamed_contig_1: invalid coordinates (3856737-3858237)
# Skipping downstream for region 1 in Ps_atrofaciens_renamed_contig_1: invalid coordinates (3906059-45004)
# Skipping upstream for region 2 in Ps_atrofaciens_renamed_contig_1: invalid coordinates (4552455-4553955)
# Skipping downstream for region 2 in Ps_atrofaciens_renamed_contig_1: invalid coordinates (4570230-45004)
# Skipping upstream for region 3 in Ps_atrofaciens_renamed_contig_1: invalid coordinates (4613552-4615052)
# Skipping downstream for region 3 in Ps_atrofaciens_renamed_contig_1: invalid coordinates (4633423-45004)
# Skipping downstream for region 1 in NCSU_AHP171_contig_1: invalid coordinates (127730-80947)
# Skipping upstream for region 2 in NCSU_AHP171_contig_1: invalid coordinates (2903478-2904978)
# Skipping downstream for region 2 in NCSU_AHP171_contig_1: invalid coordinates (2922710-80947)
# Skipping upstream for region 3 in NCSU_AHP171_contig_1: invalid coordinates (4628645-4630145)
# Skipping downstream for region 3 in NCSU_AHP171_contig_1: invalid coordinates (4668190-80947)
# Skipping upstream for region 1 in NCSU_AHP177_contig_1: invalid coordinates (1587166-1588666)
# Skipping downstream for region 1 in NCSU_AHP177_contig_1: invalid coordinates (1606057-7738)
# Skipping upstream for region 2 in NCSU_AHP177_contig_1: invalid coordinates (1977585-1979085)
# Skipping downstream for region 2 in NCSU_AHP177_contig_1: invalid coordinates (2032960-7738)
# Skipping upstream for region 3 in NCSU_AHP177_contig_1: invalid coordinates (4208919-4210419)
# Skipping downstream for region 3 in NCSU_AHP177_contig_1: invalid coordinates (4232861-7738)
# Skipping upstream for region 4 in NCSU_AHP177_contig_1: invalid coordinates (5979004-5980504)
# Skipping downstream for region 4 in NCSU_AHP177_contig_1: invalid coordinates (6017697-7738)
# Skipping upstream for region 1 in NCSU_AHP179_contig_1: invalid coordinates (2361262-2362762)
# Skipping downstream for region 1 in NCSU_AHP179_contig_1: invalid coordinates (2414392-70386)
# Skipping upstream for region 2 in NCSU_AHP179_contig_1: invalid coordinates (5185064-5186564)
# Skipping downstream for region 2 in NCSU_AHP179_contig_1: invalid coordinates (5204298-70386)

# %%
# Step4: Save summary table
output_df = pd.DataFrame(output_rows)
output_df.to_csv('extracted_regions_summary_1500.tsv', sep='\t', index=False)
